# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# Create Spark Session
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .getOrCreate()

# %%
df = spark.read.csv("D:/Documents/dataset/Uber-Jan-Feb-FOIL.csv", header=True, inferSchema=True)

# %%
import pixiedust

display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#
#         <div id="chartFiguree368420a" class="pd_save" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-e368420a")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"421db364-f80b-460e-b69b-b4fda2f96eb7":{"roots":{"references":[{"attributes":{"label":{"value":"1/24/2015"},"renderers":[{"id":"cf8b7ea5-4435-457d-94d1-a8a42dc73f0e","type":"GlyphRenderer"}]},"id":"f0810d37-7ced-4833-958f-c51d12e37f17","type":"LegendItem"},{"attributes":{"line_color":"#A31D99","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"99240b23-c013-4493-8b20-e8720487c288","type":"Line"},{"attributes":{},"id":"f63ad97f-6961-4d52-96f5-c8b1fc930d1d","type":"Selection"},{"attributes":{},"id":"a8c8398b-0b57-4a7a-9823-12a746b0e54d","type":"UnionRenderers"},{"attributes":{"line_color":"#EB7654","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"11260cbf-6288-4a17-96db-4c547262a896","type":"Line"},{"attributes":{"line_alpha":0.1,"line_color":"#1f77b4","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"b5e375ba-e1b9-4855-9a99-7463a1f3a7f7","type":"Line"},{"attributes":{"label":{"value":"2/6/2015"},"renderers":[{"id":"886c2232-843c-4af3-a1eb-ba81571a0583","type":"GlyphRenderer"}]},"id":"f84025ab-4d4d-4efe-b59a-84f5b21f4ca6","type":"LegendItem"},{"attributes":{"data_source":{"id":"de7087b0-c0c8-4f02-8c2b-33eb3a784eee","type":"ColumnDataSource"},"glyph":{"id":"1bbe075a-d36b-43ce-aaff-070bc6b0143d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b5e375ba-e1b9-4855-9a99-7463a1f3a7f7","type":"Line"},"selection_glyph":null,"view":{"id":"953fc642-869f-4dd5-8790-76052c32f6f2","type":"CDSView"}},"id":"886c2232-843c-4af3-a1eb-ba81571a0583","type":"GlyphRenderer"},{"attributes":{"line_color":"#1B068C","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id":"1bbe075a-d36b-43ce-aaff-070bc6b0143d","type":"Line"},{"attributes":{"source":{"id":"de7087b0-c0c8-4f02-8c2b-33eb3a784eee","type":"ColumnDataSource"}},"id":"953fc642-869f-4dd5-8790-76052c32f6f2","type":"CDSView"},{"attributes":{"source":{"id":"63d9e894-1cb1-4562-bbfe-ad30de8c2138","type":"ColumnDataSource"}},"id":"5dbcb72c-a6e0-453e-b721-5e312a29d252","type":"CDSView"},{"attributes":{"callback":null,"data":{"x":["B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02512","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02598","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02617","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02682","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02764","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765","B02765"],"y":[261,1181,385]},"selected":{"id":"9a0aec4b-e13c-4a6d-8e5e-506a980d1368","type":"Selection"},"selection_policy":{"id":"cd86cb28-8b77-46de-ad80-446667f8b3e0","type":"UnionRenderers"}},"id":"de7087b0-c0c8-4f02-8c2b-33eb3a784eee","type":"ColumnDataSource"},{"attributes":{},"id":"c071bd71-fcde-4922-9616-be750bab4fff","type":"Selection"},{"attributes":{},"id":"461bf53f-9252-4bac-84d8-5099c4ade01c","type":"Selection"},{"attributes":{"source":{"id":"797041de-4a8e-4aff-a9ff-b3aaf3204b52","type":"ColumnDataSource"}},"id":"8f9f9086-0822-4f8f-b6e4-60474e9cc93a","type":"CDSView"},{"attributes":{},"id":"40458cfc-cf6c-4d58-b7a2-552a4d19bb2a","type":"Selection"},{"attributes":{},"id":"4948de1c-1571-4e59-97af-269487c44186","type":"Selection"},{"attributes":{"label":{"value":"1/14/2015"},"renderers":[{"id":"9ffd97d2-c5c2-4681-81c4-34423d4f647d","type":"GlyphRenderer"}]},"id":"5f941720-44f8-4db7-92f5-abb70f7bdd35","type":"LegendItem"},{"attributes":{"line_color":"#2F0495","line_width":2,"x":{"field":"x"},"y":{"field":"y"}},"id": ...

# %%
df = pixiedust.sampleData(6)

# %%
display(df)

# %%
# Out:
# 354
